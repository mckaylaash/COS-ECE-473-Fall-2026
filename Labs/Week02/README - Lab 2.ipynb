# %% [markdown]
# # Objectives
#
# - Familiarization with smart contarcts
# - Step through OPCODE level execution of a transaction
# - Familiarize and set up web3 library and wallet APIs
# - Interacting with an ERC20 token
#
#
#
# # Walkthrough smart contract
#
# We have deployed smart contracts for the ERC20 tokens on the Sepolia testnet. The contracts can be found on etherscan here: [LUSD](https://sepolia.etherscan.io/address/0xa2039612e374ad2365361DF0FF34399A4f0A1e58), [TIGER](https://sepolia.etherscan.io/address/0x706d4199f1333258F6a3386Db87792Ff6AcB04Ae). We will pretend that the Lab USD token has a value of 1 USD, and the TIGER token value is decided by the market (i.e. participants such as you buying/selling these tokens).
#
# Let us now go through the contract and describe what each ```function``` does.

# %% [markdown]
# ### What does ```balanceOf``` and ```totalSupply``` do?

# %% [markdown]
# ### What does ```transfer``` and ```transferFrom``` do ? Which of them needs you to run ```approve``` before it executes correctly ?

# %% [markdown]
# ### What events can be emitted by the contract ? [What is their use](https://consensys.net/blog/developers/guide-to-events-and-logs-in-ethereum-smart-contracts/) ?

# %% [markdown]
# ### How does the contract respond to airdrop requests ?

# %% [markdown]
# # Requesting tokens
#
# To request the tokens we shall be using in the future for some in-class labs, we are going to use the ```web3``` library in python. The installation instructions can be found [here](https://web3py.readthedocs.io/en/v5/quickstart.html). We will view our transactions on the [Sepolia testnet etherscan](https://sepolia.etherscan.io/).
#
# We now send a transaction that uses this API to request some of the Lab ERC20 tokens from a [faucet contract](https://sepolia.etherscan.io/address/0x681878325277B9cC3cFdD3922321AcedD94D97b9). The faucet allows each registered wallet to redeem a fixed number of tokens per day. The code used to do that has to be written below.
#
# ### Setup Web3 API
# First, we connect your wallet to a Web3 API - this is a service that connects you to the Ethereum blockchain via a simple URL.
#
# To do that, first create a free account on [Infura](https://app.infura.io/register)(using any email ID).
#
# Once you log in, you would see your Infura API key under the project name you had given. Use that key in the following code.

# %%
pip install web3
# Out:
# Collecting web3
#   Using cached web3-8.0.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting aiohttp>=3.7.4.post0 (from web3)
#   Downloading aiohttp-3.14.3-cp312-cp312-macosx_11_0_arm64.whl.metadata (8.3 kB)
# Collecting eth-abi>=6 (from web3)
#   Using cached eth_abi-6.0.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting eth-account>=0.14 (from web3)
#   Using cached eth_account-0.14.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting eth-hash>=0.5.1 (from eth-hash[pycryptodome]>=0.5.1->web3)
#   Using cached eth_hash-0.8.0-py3-none-any.whl.metadata (4.1 kB)
# Collecting eth-typing>=5.0.0 (from web3)
#   Using cached eth_typing-6.0.0-py3-none-any.whl.metadata (3.1 kB)
# Collecting eth-utils>=5.3.0 (from web3)
#   Using cached eth_utils-6.0.0-py3-none-any.whl.metadata (5.6 kB)
# Collecting hexbytes>=2 (from web3)
#   Using cached hexbytes-2.0.0-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: pydantic>=2.4 in /opt/miniconda3/lib/python3.12/site-packages (from web3) (2.13.2)
# Collecting pyunormalize>=15 (from web3)
#   Using cached pyunormalize-17.0.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: requests>=2.23.0 in /opt/miniconda3/lib/python3.12/site-packages (from web3) (2.33.1)
# Collecting websockets>=14 (from web3)
#   Using cached websockets-17.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.3 kB)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp>=3.7.4.post0->web3)
#   Downloading aiohappyeyeballs-2.7.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp>=3.7.4.post0->web3)
#   Using cached aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting attrs>=17.3.0 (from aiohttp>=3.7.4.post0->web3)
#   Using cached attrs-26.1.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp>=3.7.4.post0->web3)
#   Downloading frozenlist-1.8.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (20 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp>=3.7.4.post0->web3)
#   Downloading multidict-6.8.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.0 (from aiohttp>=3.7.4.post0->web3)
#   Downloading propcache-0.5.2-cp312-cp312-macosx_11_0_arm64.whl.metadata (16 kB)
# Requirement already satisfied: typing_extensions>=4.4 in /opt/miniconda3/lib/python3.12/site-packages (from aiohttp>=3.7.4.post0->web3) (4.15.0)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp>=3.7.4.post0->web3)
#   Downloading yarl-1.24.5-cp312-cp312-macosx_11_0_arm64.whl.metadata (103 kB)
# Requirement already satisfied: idna>=2.0 in /opt/miniconda3/lib/python3.12/site-packages (from yarl<2.0,>=1.17.0->aiohttp>=3.7.4.post0->web3) (3.11)
# Collecting parsimonious<0.11.0,>=0.10.0 (from eth-abi>=6->web3)
#   Using cached parsimonious-0.10.0-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: regex>=2022.3.15 in /opt/miniconda3/lib/python3.12/site-packages (from parsimonious<0.11.0,>=0.10.0->eth-abi>=6->web3) (2026.4.4)
# Collecting bitarray>=2.4 (from eth-account>=0.14->web3)
#   Using cached bitarray-3.11.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (38 kB)
# Collecting eth-keyfile>=0.10 (from eth-account>=0.14->web3)
#   Using cached eth_keyfile-0.10.0-py3-none-any.whl.metadata (9.8 kB)
# Collecting eth-keys>=0.5 (from eth-account>=0.14->web3)
#   Using cached eth_keys-0.8.0-py3-none-any.whl.metadata (12 kB)
# Collecting eth-rlp>=3 (from eth-account>=0.14->web3)
#   Using cached eth_rlp-3.0.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting rlp>=2 (from eth-account>=0.14->web3)
#   Using cached rlp-5.0.0-py3-none-any.whl.metadata (2.1 kB)
# Collecting ckzg>=2 (from eth-account>=0.14->web3)
#   Using cached ckzg-2.1.8-cp312-cp312-macosx_11_0_arm64.whl.metadata (887 bytes)
# Collecting pycryptodome<4,>=3.6.6 (from eth-hash[pycryptodome]>=0.5.1->web3)
#   Using cached pycryptodome-3.23.0-cp37-abi3-macosx_10_9_universal2.whl.metadata (3.4 kB)
# Collecting py_ecc>=5.2.0 (from eth-keyfile>=0.10->eth-account>=0.14->web3)
#   Using cached py_ecc-8.0.0-py3-none-any.whl.metadata (3.1 kB)
# Collecting cytoolz>=0.10.1 (from eth-utils>=5.3.0->web3)
#   Using cached cytoolz-1.1.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (5.2 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/miniconda3/lib/python3.12/site-packages (from pydantic>=2.4->web3) (0.6.0)
# Requirement already satisfied: pydantic-core==2.46.2 in /opt/miniconda3/lib/python3.12/site-packages (from pydantic>=2.4->web3) (2.46.2)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/miniconda3/lib/python3.12/site-packages (from pydantic>=2.4->web3) (0.4.2)
# Collecting toolz>=0.8.0 (from cytoolz>=0.10.1->eth-utils>=5.3.0->web3)
#   Using cached toolz-1.1.0-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/miniconda3/lib/python3.12/site-packages (from requests>=2.23.0->web3) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.26 in /opt/miniconda3/lib/python3.12/site-packages (from requests>=2.23.0->web3) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in /opt/miniconda3/lib/python3.12/site-packages (from requests>=2.23.0->web3) (2026.4.22)
# Using cached web3-8.0.0-py3-none-any.whl (1.4 MB)
# Downloading aiohttp-3.14.3-cp312-cp312-macosx_11_0_arm64.whl (511 kB)
# Downloading multidict-6.8.0-cp312-cp312-macosx_11_0_arm64.whl (49 kB)
# Downloading yarl-1.24.5-cp312-cp312-macosx_11_0_arm64.whl (97 kB)
# Downloading aiohappyeyeballs-2.7.1-py3-none-any.whl (15 kB)
# Using cached aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Using cached attrs-26.1.0-py3-none-any.whl (67 kB)
# Using cached eth_abi-6.0.0-py3-none-any.whl (53 kB)
# Using cached parsimonious-0.10.0-py3-none-any.whl (48 kB)
# Using cached eth_account-0.14.0-py3-none-any.whl (586 kB)
# Using cached bitarray-3.11.0-cp312-cp312-macosx_11_0_arm64.whl (166 kB)
# Using cached ckzg-2.1.8-cp312-cp312-macosx_11_0_arm64.whl (96 kB)
# Using cached eth_hash-0.8.0-py3-none-any.whl (8.0 kB)
# Using cached pycryptodome-3.23.0-cp37-abi3-macosx_10_9_universal2.whl (2.5 MB)
# Using cached eth_keyfile-0.10.0-py3-none-any.whl (9.5 kB)
# Using cached eth_keys-0.8.0-py3-none-any.whl (20 kB)
# Using cached eth_rlp-3.0.0-py3-none-any.whl (15 kB)
# Using cached eth_typing-6.0.0-py3-none-any.whl (19 kB)
# Using cached eth_utils-6.0.0-py3-none-any.whl (102 kB)
# Using cached cytoolz-1.1.0-cp312-cp312-macosx_11_0_arm64.whl (991 kB)
# Downloading frozenlist-1.8.0-cp312-cp312-macosx_11_0_arm64.whl (50 kB)
# Using cached hexbytes-2.0.0-py3-none-any.whl (18 kB)
# Downloading propcache-0.5.2-cp312-cp312-macosx_11_0_arm64.whl (55 kB)
# Using cached py_ecc-8.0.0-py3-none-any.whl (47 kB)
# Using cached pyunormalize-17.0.0-py3-none-any.whl (51 kB)
# Using cached rlp-5.0.0-py3-none-any.whl (19 kB)
# Using cached toolz-1.1.0-py3-none-any.whl (58 kB)
# Using cached websockets-17.1-cp312-cp312-macosx_11_0_arm64.whl (214 kB)
# Installing collected packages: ckzg, websockets, toolz, pyunormalize, pycryptodome, propcache, parsimonious, multidict, hexbytes, frozenlist, eth-typing, eth-hash, bitarray, attrs, aiohappyeyeballs, yarl, cytoolz, aiosignal, eth-utils, aiohttp, rlp, py_ecc, eth-keys, eth-abi, eth-rlp, eth-keyfile, eth-account, web3
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28/28 [web3]2m27/28 [web3]eys]]me]
# Successfully installed aiohappyeyeballs-2.7.1 aiohttp-3.14.3 aiosignal-1.4.0 attrs-26.1.0 bitarray-3.11.0 ckzg-2.1.8 cytoolz-1.1.0 eth-abi-6.0.0 eth-account-0.14.0 eth-hash-0.8.0 eth-keyfile-0.10.0 eth-keys-0.8.0 eth-rlp-3.0.0 eth-typing-6.0.0 eth-utils-6.0.0 frozenlist-1.8.0 hexbytes-2.0.0 multidict-6.8.0 parsimonious-0.10.0 propcache-0.5.2 py_ecc-8.0.0 pycryptodome-3.23.0 pyunormalize-17.0.0 rlp-5.0.0 toolz-1.1.0 web3-8.0.0 websockets-17.1 yarl-1.24.5
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import web3
from web3 import Web3
from datetime import datetime, timedelta

w3 = Web3(Web3.HTTPProvider('https://sepolia.infura.io/v3/df0fcce70d1c4160bae1e5878c6b3bcf'))

print(w3.eth.block_number) #Check if the notebook is connected to the Infura node
print(w3.__dict__)
# Out:
# 11703278
# {'manager': <web3.manager.RequestManager object at 0x126aae3c0>, 'codec': <eth_abi.codec.ABICodec object at 0x1277db380>, 'eth': <web3.eth.eth.Eth object at 0x1277daf30>, 'net': <web3.net.Net object at 0x1277dbd70>, 'geth': <web3.geth.Geth object at 0x1277dafc0>, 'tracing': <web3.tracing.Tracing object at 0x1277dbcb0>, 'testing': <web3.testing.Testing object at 0x1277dbaa0>, '_ens': <web3._utils.empty.Empty object at 0x12622b2c0>}

# %% [markdown]
# ### Setup your ETH account details

# %%
# Wallet details

public_address = '0xf8013f6c6259c7962905233a62a03E502C4Ad763' # see metamask for this
private_key = '74ea35d17ed7c3c89c467b02af4865dfc11b26dbeef55705f55f4916fb06bae5' # see metamask for this

# %% [markdown]
# ### Set up a contract instance
# Now, we send a request transaction to the faucet, signed by your private key.

# %%
# Define the TigerFaucet contract to connect to

contract_addr = '0x681878325277B9cC3cFdD3922321AcedD94D97b9' # faucet
abi_contract = '[{"inputs":[],"stateMutability":"nonpayable","type":"constructor"},{"inputs":[{"internalType":"address[]","name":"user_list","type":"address[]"},{"internalType":"address","name":"token_address","type":"address"}],"name":"deRegisterUsers","outputs":[],"stateMutability":"nonpayable","type":"function"},{"inputs":[{"internalType":"address","name":"user_address","type":"address"},{"internalType":"address","name":"token_address","type":"address"}],"name":"getLatestRequestTimestamp","outputs":[{"internalType":"uint256","name":"","type":"uint256"}],"stateMutability":"view","type":"function"},{"inputs":[{"internalType":"address","name":"user_address","type":"address"},{"internalType":"address","name":"token_address","type":"address"}],"name":"getRegistrationStatus","outputs":[{"internalType":"bool","name":"","type":"bool"}],"stateMutability":"view","type":"function"},{"inputs":[],"name":"manager","outputs":[{"internalType":"address","name":"","type":"address"}],"stateMutability":"view","type":"function"},{"inputs":[{"internalType":"address[]","name":"user_list","type":"address[]"},{"internalType":"address","name":"token_address","type":"address"}],"name":"registerUsers","outputs":[],"stateMutability":"nonpayable","type":"function"},{"inputs":[{"internalType":"contract IERC20","name":"token","type":"address"}],"name":"requestTokens","outputs":[],"stateMutability":"nonpayable","type":"function"},{"inputs":[{"internalType":"contract IERC20","name":"token","type":"address"}],"name":"retrieveFaucetAmount","outputs":[{"internalType":"uint256","name":"","type":"uint256"}],"stateMutability":"view","type":"function"},{"inputs":[{"internalType":"contract IERC20","name":"token","type":"address"}],"name":"retrieveFaucetBalance","outputs":[{"internalType":"uint256","name":"","type":"uint256"}],"stateMutability":"view","type":"function"},{"inputs":[{"internalType":"address","name":"token_address","type":"address"},{"internalType":"uint256","name":"value","type":"uint256"}],"name":"set_faucet_amount","outputs":[],"stateMutability":"nonpayable","type":"function"}]' # see the "Code" section of the faucet contract on etherscan
contract = w3.eth.contract(contract_addr, abi=abi_contract)

# Define the address of the ERC20 token you want

token_addr = '0x706d4199f1333258F6a3386Db87792Ff6AcB04Ae' # TIGER

# %% [markdown]
# ### Create transaction data

# %%
### Create transaction data
txn = contract.functions.requestTokens(token_addr).build_transaction(
    {
        'nonce':w3.eth.get_transaction_count(public_address),
        'from':public_address,
    }
)

# %% [markdown]
# ### Sign and post transaction
# You should see the hash of your transaction printed.

# %%
# Post transaction

signed_txn = w3.eth.account.sign_transaction(txn, private_key) # Sign the txn with your private key 
txn_hash = w3.eth.send_raw_transaction(signed_txn.raw_transaction) # Send it onto the chain

# %%
print("Hash of swap transaction : ",Web3.to_hex(txn_hash)) # Search the txn hash on etherscan to see if it got confirmed
# Out:
# Hash of swap transaction :  0xb131fc24925664872d1452fea785cd22b48126f6d078b5944d5dabbc03e3d93d

# %% [markdown]
# ## Request tokens through Etherscan
#
# Verified contracts on Etherscan allow you to interact with functions on the contract.
# Open the [Tiger Faucet](https://sepolia.etherscan.io/address/0x681878325277B9cC3cFdD3922321AcedD94D97b9) contract by providing it's address. You can now access the contract's read and write functions.
# Go to the ``write tab``, connect your metamask wallet and call the ``requestTokens`` function by providing your wallet's public address and the TIGER token's contract address. Confirm the transaction on the metamask prompt.

# %% [markdown]
# # Add to MetaMask

# %% [markdown]
# - The token balances can now be tracked via MetaMask using the contract addresses of each token.
# - Use the "Import Tokens" link at the bottom of your MetaMask.
# - Enter the smart contract address for an ERC20 tokens we would be using in the class.
# - Do this for each of the tokens - TIGER and LUSD
